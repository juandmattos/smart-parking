# %% [markdown]
# # Smart Parking System Producer

# %% [markdown]
# **Se realiza primeramente un código que realice datos simulados para poder enviar datos a través de Apache Kafka mediante un topico en especifico**
#
# ## 1.- Se realiza la importación de las principales librerías a usar
#
# 1. Kafka - Para realizar la conexión a Apache Kafka y enviar data al topico correspondiente
# 2. Random - Generación de data aleatoria según distintas listas
# 3. Json - Para envío de un json mediante el producer
# 4. Datetime - Obtener fechas y distintos tipos de transformaciones posibles
# 5. time - Necesario para realizar sleeps de 1 segundo por cada envío

# %%
import random
import json
import uuid
import time
import os
import requests
import pyowm
from kafka import KafkaProducer
from datetime import datetime, timedelta

# %% [markdown]
# ## 2.- Primeros Valores a necesitar simular
#
# #### El Json en la entrada del sistema tiene la siguiente característica:
#
# {
#   "parking_name":"Parking Tres Cruces",
#   "parking_address":"Bvr. Gral. Artigas 1825, Montevideo, Uruguay",
#   "description":"Parking que se encuentra en el shopping de tres cruces",
#   "timestamp":"2022-05-03 11:12:51",
#   "device_address":"0013A2004147A0E5",
#   "device_latitude":-34.89429684062983,
#   "device_longitude":-56.165979541252796,
#   "temperature":17.01,
#   "humidity":67,
#   "parking_uuid":"cf0158d3-42e1-4744-b477-cf45b7de960a",
#   "parking_id":"1",
#   "level_id":"1",
#   "area_id":"1",
#   "area_name":"A",
#   "spots":"5",
#   "slots":[
#     {
#       "slot_id":"1",
#       "state":true
#     },
#     {
#       "slot_id":"2",
#       "state":false
#     },
#     {
#       "slot_id":"3",
#       "state":true
#     },
#     {
#       "slot_id":"4",
#       "state":true
#     },
#     {
#       "slot_id":"5",
#       "state":true
#     }
#   ]
# }
#
# #### Se realiza carga de principales variables para el Simulador de Productor:

# %%
# preguntar por cual dispositivo quiere ejecutar
# 
with open(dirgeneral+parking+'/'+parking+'devices.txt', 'r') as f:
    file = f.readlines()

print("Seleccione alguno de los siguientes dispositivos virtuales: ")
for i in range(1, len(file)+1):
    line = file[i-1].replace("\n","")
    print(str(i)+".- "+line)
num = input("Ingrese su opción (1): ").

if num == ""
if deviceAddress == "":
    deviceAddress = "0013A2004147A0AB"
data['device_address'] = deviceAddress 
# with open(dirgeneral+parking+'/'+parking+'ActiveDevices.txt', 'w') as f    
# for line in file:
#     line = line.replace("\n","")
# Out:
# Seleccione alguno de los siguientes dispositivos virtuales:
# 1.- 2C2E200A005F5CED
# 2.- 3F949883854CD50B
# 3.- B2FF598BBE24008D
# 4.- 4106453F83B24DD7
# 5.- C12DF77EA6B43751
# 6.- A294F52C127B6E79
# 7.- 672D2AB3BE503217
# 8.- 790FA75B139453FF
# 9.- 1FC9B9F9BC0714A4
# 10.- 9A653847AA9D63AA
# Ingrese su opción (1): 1

# %%
# Load a JSON Model
dirgeneral = "/opt/smart-parking/Python/Generator/Parkings/"
directorios = os.listdir(dirgeneral)

print("Indique en número sobre que Parking desea realizar la simulación: \n")
for i in range(1, len(directorios)+1):
    print(str(i)+".- "+directorios[i-1])

num = input("Ingrese su opción (1): ")
if num == "":
    parking = directorios[0]
else:
    parking = directorios[int(num) - 1]
# Out:
# Indique en número sobre que Parking desea realizar la simulación:
#
# 1.- PuntaCarretasShopping
# 2.- TresCrucesShopping
# Ingrese su opción (1): 2

# %%
# Se establecen los rangos a establecer con random

dirgeneral = "/opt/smart-parking/Python/Generator/Parkings/"
directorios = os.listdir(dirgeneral)

print("Indique en número sobre que Parking desea realizar la simulación: \n")
for i in range(1, len(directorios)+1):
    print(str(i)+".- "+directorios[i-1])
num = input("Ingrese su opción (1): ")
if num == "":
    parking = directorios[0]
else:
    parking = directorios[int(num) - 1]

with open(dirgeneral+parking+'/producerTresXShoppingv2.json') as f:
    data = json.load(f)

### AQUI VA LA PREGUNTA DEL DEVICE
    

if deviceAddress == "":
    deviceAddress = "0013A2004147A0AB"
data['device_address'] = deviceAddress 

num_puestos = input("Indique cuantos puestos desea simular (10): ")
if num_puestos == "":
    num_puestos = 10
else:
    num_puestos = int(num_puestos)
data['spots'] = str(num_puestos)

# Format the slots object data
for i in range(1,num_puestos + 1):
    data['slots'].append({})
    
nivel = input("Indique el Nivel del estacionamiento (1): ")
if nivel == "":
    nivel = "1"
data['level_id'] = nivel 
    
area = input("Indique el numero de sector del estacionamiento (1): ")
if area == "":
    area = "1"
data['area_id'] = area 
areaName = input("Indique el nombre de sector del estacionamiento (A): ")
if areaName == "":
    areaName = "A"
data['area_name'] = areaName

# Values used to random function
lista_estado_puestos = [False for n in range(1,num_puestos + 1)]
lista_auxTemp = [0 for n in range(1, num_puestos + 1)]
#rango = [2, 5, 10, 20, 30, 45, 60, 120, 240]
rango = [1, 2]
slot_states = [True, False]

# Rangos de fechas para horario nocturno, en el cual los carros se encuentran dentro del Parking
Turno_inicio = str(datetime.now().day) +'/'+str(datetime.now().month) +'/'+str(datetime.now().year) +' 22:00:00'
Turno_final = str(datetime.now().day + 1) +'/'+str(datetime.now().month) +'/'+str(datetime.now().year) +' 08:00:00'

# Obtener fecha de primera consulta para el tiempo
APIKEY='055bcf46839359ea922b925c3d7cd860'        # your API Key here as string
owm = pyowm.OWM(APIKEY)                       # Use API key to get data
mgr = owm.weather_manager()
weather = mgr.weather_at_place('Montevideo,UY').weather
getTimeWeather = datetime.now() + timedelta(minutes=30)
data['temperature'] = weather.temperature(unit='celsius')['temp']
data['humidity'] = weather.humidity
data['timestamp'] = datetime.now().strftime('%Y-%m-%d %H:%M:%S')

# Initialize a Kafka Producer
producer = KafkaProducer(bootstrap_servers=['hadoop-namenode:9092'], api_version=(0,10,0), value_serializer=lambda x: json.dumps(x).encode('utf-8'))
topic = data['parking_id']+"_"+data['level_id']+"_"+data['area_id']+"_"+data['area_name']
print(topic)
# Out:
# Indique cuantos puestos desea simular (10):
# Indique el Nivel del estacionamiento (1):
# Indique el numero de sector del estacionamiento (1):
# Indique el nombre de sector del estacionamiento (A):
# 1_1_1_A

# %% [markdown]
# ## Loop para el envío de datos continuo con ciertas modificaciones en su estructura

# %%
while True:
    now = datetime.now()
    if now >= datetime.strptime(Turno_inicio, '%d/%m/%Y %H:%M:%S') and now <= datetime.strptime(Turno_final, '%d/%m/%Y %H:%M:%S'):
        #auxTemp1 = auxTemp2 = auxTemp3 = auxTemp4 = auxTemp5 = 0
        #status_slot1 = status_slot2 = status_slot3 = status_slot4 = status_slot5 = False
        lista_estado_puestos = [False for n in range(1,num_puestos + 1)]
        lista_auxTemp = [0 for n in range(1, num_puestos + 1)]
    else:
        
        Turno_inicio = str(now.day) +'/'+str(now.month) +'/'+str(now.year) +' 22:00:00'
        Turno_final = str(now.day + 1) +'/'+str(now.month) +'/'+str(now.year) +' 08:00:00'
        
        for i in range(0,len(lista_estado_puestos)):
            if lista_auxTemp[i] == 0:
                minutes = random.choice(rango)
                lista_auxTemp[i] = now + timedelta(minutes=minutes)
                lista_estado_puestos[i] = random.choice(slot_states)
            elif now > lista_auxTemp[i]:
                minutes = random.choice(rango)
                lista_auxTemp[i] = now + timedelta(minutes=minutes)
                lista_estado_puestos[i] = random.choice(slot_states)
        
        if getTimeWeather.hour == now.hour and getTimeWeather.minute == now.minute:
            weather = mgr.weather_at_place('Montevideo,UY').weather
            data['temperature'] = weather.temperature(unit='celsius')['temp']
            data['humidity'] = weather.humidity
            getTimeWeather = now + timedelta(minutes=30)
        else:
            data['temperature'] = weather.temperature(unit='celsius')['temp']
            data['humidity'] = weather.humidity

    data['timestamp'] = now.strftime('%Y-%m-%d %H:%M:%S')
     
    for i in range(0,len(lista_estado_puestos)):
        data['slots'][i]['slot_id'] = str(i+1)
        data['slots'][i]['state'] = lista_estado_puestos[i]
    
    print(now.strftime('%Y-%m-%d %H:%M:%S')+" - "+str(data) + "\n")
    
    producer.send(topic, value=data)
    
    time.sleep(1)
# Out:
# 2022-05-03 22:37:54 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:37:54', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:37:55 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:37:55', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:37:56 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:37:56', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:37:57 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:37:57', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:37:58 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:37:58', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:37:59 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:37:59', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:00 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:00', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:01 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:01', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:03 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:03', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:04 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:04', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
# 2022-05-03 22:38:05 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:05', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:06 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:06', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:07 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:07', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:08 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:08', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:09 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:09', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:10 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:10', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:11 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:11', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:12 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:12', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:13 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:13', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:14 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:14', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
# 2022-05-03 22:38:15 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:15', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:16 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:16', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:17 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:17', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:18 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:18', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:19 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:19', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:20 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:20', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:21 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:21', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:22 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:22', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:23 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:23', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:24 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:24', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
# 2022-05-03 22:38:25 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:25', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:26 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:26', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:27 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:27', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:28 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:28', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:29 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:29', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:30 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:30', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:31 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:31', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:32 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:32', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:33 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:33', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:34 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:34', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
# 2022-05-03 22:38:35 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:35', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:36 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:36', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:37 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:37', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:38 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:38', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:39 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:39', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:40 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:40', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:41 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:41', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:42 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:42', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:43 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:43', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:44 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:44', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
# 2022-05-03 22:38:45 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:45', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:46 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:46', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:47 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:47', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:38:48 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:38:48', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# ...
#
# 2022-05-03 22:50:52 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:50:52', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:50:53 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:50:53', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:50:54 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:50:54', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:50:55 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:50:55', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:50:56 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:50:56', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:50:57 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:50:57', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
# 2022-05-03 22:50:58 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:50:58', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:50:59 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:50:59', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:51:00 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:51:00', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:51:01 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:51:01', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:51:02 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:51:02', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:51:03 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:51:03', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:51:04 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:51:04', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:51:05 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:51:05', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:51:06 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:51:06', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:51:07 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:51:07', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
# 2022-05-03 22:51:08 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:51:08', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
#
# 2022-05-03 22:51:09 - {'parking_name': 'Parking Tres Cruces', 'parking_address': 'Bvr. Gral. Artigas 1825, Montevideo, Uruguay', 'description': 'Parking que se encuentra en el shopping de tres cruces', 'timestamp': '2022-05-03 22:51:09', 'device_address': '0013A2004147A0E5', 'device_latitude': -34.89429684062983, 'device_longitude': -56.165979541252796, 'temperature': 10.84, 'humidity': 93, 'parking_uuid': 'cf0158d3-42e1-4744-b477-cf45b7de960a', 'parking_id': '1', 'level_id': '1', 'area_id': '1', 'area_name': 'A', 'spots': '5', 'slots': [{'slot_id': '1', 'state': False}, {'slot_id': '2', 'state': False}, {'slot_id': '3', 'state': False}, {'slot_id': '4', 'state': False}, {'slot_id': '5', 'state': False}, {'slot_id': '6', 'state': False}, {'slot_id': '7', 'state': False}, {'slot_id': '8', 'state': False}, {'slot_id': '9', 'state': False}, {'slot_id': '10', 'state': False}]}
